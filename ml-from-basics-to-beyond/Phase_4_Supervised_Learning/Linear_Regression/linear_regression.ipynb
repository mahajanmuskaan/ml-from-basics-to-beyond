# %% [markdown]
# Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\MUSKAAN\Documents\M.E Folder\ML&AI\Machine Learning Journey\ml-from-basics-to-beyond\Phase_4_Supervised_Learning\Linear_Regression\placement.csv")
data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
scatter_plot = plt.scatter(data["cgpa"], data["package"])
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.title("Scatter Plot of CGPA vs Package")
plt.show()
